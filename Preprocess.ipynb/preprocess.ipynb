# %%
import pandas as pd

df = pd.read_csv("./data/CHALLENGER_gamedata_2023-09-22_10000(1).csv")
df
# Out:
#         summonerName championName   win  kills  deaths  assists  \
# 0            sparkle         Yone  True      4       3        7
# 1             시작시작시작      Nidalee  True      7       4        6
# 2            Damn JG     Tristana  True      5       4        4
# 3     dnasojiayin7ox       Ezreal  True      6       2        7
# 4         haohao sup         Rell  True      1       5        9
# ...              ...          ...   ...    ...     ...      ...
# 9961            ytrr       Darius  True      6       5        3
# 9962       Like 1999       LeeSin  True     11       3        7
# 9963    afreeca 김태연         Neeko  True      7       3        9
# 9964             xi1        Nilah  True      2       5        7
# 9965       lanpangzi        Leona  True      0       7       10
#
#       totalDamageDealtToChampions  allInPings  assistMePings  baitPings  ...  \
# 0                           17827           0              1          0  ...
# ...

# %%
corrdf = df.corr(numeric_only=True)

# %%
corrdf.to_csv('./data/corr_matrix.csv', sep = ',', na_rep='NaN')

# %%
l = corrdf.loc[(corrdf['win']>0.2)|(corrdf['win']<-0.2)]
a = list(l['win'].index)
len(a)
# Out:
# 48
